# %%
from selectorlib import Extractor
import os
import csv
import re
import json
import scrapy
import collections
import xlsxwriter
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from snownlp import SnowNLP

# %%
def create_directory(folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)

# %%
def does_file_exist(path):
    return os.path.isfile(path)

# %%
def write_to_file(path,data):
   with open(path, 'a') as file:
        file.write(data + '\n')

# %%
def create_new_file(path):
    f = open(path,'w')
    f.write("")
    f.close()

# %%
def get_details(directory, url):
    try:
        PATH = '/Users/williammeikle/Downloads/chromedriver 8'
        driver = webdriver.Chrome(PATH)
        driver.get(url)
        try:
            date = driver.find_element_by_class_name('post-handle-publish')
            print('\nDate: \n'+'\n' + date.text)
            write_to_file(directory + '/articles.txt', '\nDate: \n'+'\n' + date.text)
        except NoSuchElementException:
            print('\nDate: \n')
            write_to_file(directory + '/articles.txt', "\n Date: \n")
            print('Empty')
            write_to_file(directory + '/articles.txt', '\n Empty \n')
        title = driver.find_element_by_class_name('post-title')
        print('\nTitle \n')
        write_to_file(directory + '/articles.txt', "\n Title: \n")
        print(str(title.text))
        write_to_file(directory + '/articles.txt', title.text)
        try:
            paragraphs = driver.find_element_by_class_name('tz-paragraph')
            print('\nParagraphs \n')
            write_to_file(directory + '/articles.txt', "\n Paragraphs: \n")
            print(str(paragraphs.text))
            write_to_file(directory + '/articles.txt', paragraphs.text)
        except NoSuchElementException:
            print('\nParagraphs \n')
            write_to_file(directory + '/articles.txt', "\n Paragraphs: \n")
            print('Empty')
            write_to_file(directory + '/articles.txt', '\n Empty \n')
        try:
            comments = driver.find_elements_by_class_name('reply-detail')
            print('\nComments \n')
            write_to_file(directory + '/articles.txt', "\n Comments: \n")
            for comment in comments:
                print(str(comment.text) + '\n')
                write_to_file(directory + '/articles.txt', comment.text)
        except NoSuchElementException:
            print('\nComments \n')
            write_to_file(directory + '/articles.txt', "\n Comments: \n")
            print('Empty')
            write_to_file(directory + '/articles.txt', "\n Empty \n")
        try:
            subcomments = driver.find_elements_by_class_name('reply-sub-front')
            print('\nSubComments \n')
            write_to_file(directory + '/articles.txt', "\n SubComments: \n")
            for subcomment in set(subcomments):
                print(str(subcomment.text) + '\n')
                write_to_file(directory + '/articles.txt', subcomment.text)
        except NoSuchElementException:
            print('\nSubComments \n')
            write_to_file(directory + '/articles.txt', "\n SubComments: \n")
            print('Empty')
            write_to_file(directory + '/articles.txt', "\n Empty \n")
        driver.close()
    except NoSuchElementException:
        print('Empty')

# %%
def main_scraper(url,directory):
    create_directory(directory)
    PATH = '/Users/williammeikle/Downloads/chromedriver 8'
    driver = webdriver.Chrome(PATH)
    driver.get(url)
    continue_link = driver.find_element_by_tag_name('a')
    elems = driver.find_elements_by_xpath("//a[@href]")
    for elem in set(elems):
        if 'thread' and '6830271' in str(elem.get_attribute("href")):
            print("url: " + elem.get_attribute("href"))
            elem_formatted = "url: " + elem.get_attribute("href")
            if does_file_exist(directory + "/articles.txt") is False:
                create_new_file(directory + "/articles.txt")
            write_to_file(directory + '/articles.txt', elem_formatted)
            get_details(directory, elem.get_attribute("href"))
        elif 'thread' and '6830286' in str(elem.get_attribute("href")):
            print("url: " + elem.get_attribute("href"))
            elem_formatted = "url: " + elem.get_attribute("href")
            if does_file_exist(directory + "/articles.txt") is False:
                create_new_file(directory + "/articles.txt")
            write_to_file(directory + '/articles.txt', elem_formatted)
            get_details(directory, elem.get_attribute("href"))
        else:
            continue

# %%
with open("ModelYAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('http://club.autohome.com.cn/bbs/forum-c-5769-1.html#pvareaid=3454448','ModelYAutoHomeBlog')

# %%
with open("Model3AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5346-1.html#pvareaid=3454448','Model3AutoHomeBlog')

# %%
with open("ModelSAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-2357-1.html#pvareaid=3454448','ModelSAutoHomeBlog')

# %%
with open("ModelXAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-2664-1.html#pvareaid=3454448','ModelXAutoHomeBlog')

# %%
with open("ID-6XAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-6035-1.html#pvareaid=2108152','ID-6XAutoHomeBlog')

# %%
with open("ID4XAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5511-1.html#pvareaid=3454448','ID4XAutoHomeBlog')

# %%
with open("ID3AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-6265-1.html#pvareaid=3454448','ID3AutoHomeBlog')

# %%
with open("i3AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-6544-1.html#pvareaid=3454448','i3AutoHomeBlog')

# %%
with open("iX3AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5758-1.html#pvareaid=3454448', 'iX3AutoHomeBlog')

# %%
with open("BMW5AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-4350-1.html#pvareaid=3454448','BMW5AutoHomeBlog')

# %%
with open("MustangMach-EAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-6029-1.html#pvareaid=3454448','MustangMach-EAutoHomeBlog')

# %%
with open("TerritoryAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5339-1.html#pvareaid=3454448','TerritoryAutoHomeBlog')

# %%
with open("TuyueAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5558-1.html#pvareaid=3454448', 'TuyueAutoHomeBlog')

# %%
with open("Q5EtronAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-6336-1.html#pvareaid=3454448', 'Q5EtronAutoHomeBlog')

# %%
with open("EtronAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5765-1.html#pvareaid=3454448', 'EtronAutoHomeBlog')

# %%
with open("MagotanAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5062-1.html#pvareaid=3454448', 'MagotanAutoHomeBlog')

# %%
with open("TanyueAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5061-1.html#pvareaid=3454448', 'TanyueAutoHomeBlog')

# %%
with open("X5AutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-4348-1.html#pvareaid=3454448', 'X5AutoHomeBlog')

# %%
with open("PassatAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-4904-1.html#pvareaid=3454448', 'PassatAutoHomeBlog')

# %%
with open("TiguanAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-4746-1.html#pvareaid=3454448', 'TiguanAutoHomeBlog')

# %%
with open("TouregAutoHomeBlog/articles.txt", 'r+') as f:
    f.truncate(0)

# %%
main_scraper('https://club.autohome.com.cn/bbs/forum-c-5063-1.html#pvareaid=3454448', 'TouregAutoHomeBlog')

# %%
def main_download(directory):
    workbook = xlsxwriter.Workbook(directory + '.xlsx')
    worksheet = workbook.add_worksheet()
    file = open(directory + "/articles.txt", 'r')
    data = file.read()
    list1 = words_list
    d = "url"
    newlines = (data.split(d))
    t=0
    worksheet.write('B1', 'Date')
    worksheet.write('C1', 'Text-Length')
    worksheet.write('D1', 'Sentiments')
    row = 1 
    for line in newlines: 
        row = row + 1
        pattern = "\d{4}[-]\d{2}[-]\d{2}"
        date = str(re.search(pattern, line))
        newdate = str(date[-12:-2])
        newdate.replace('-', '')
        worksheet.write('B' + str(row), newdate)
    row = 1
    for line in newlines: 
        row = row + 1
        start = line.find("Paragraph") + len("Paragraph")
        end = line.find("Comments")
        substring = line[start:end]
        worksheet.write('C'+str(row), len(substring))
    row = 1
    for line in newlines:
        row = row + 1
        try:
            s = SnowNLP(line)
            worksheet.write('D'+str(row), s.sentiments)
        except ZeroDivisionError:
            continue
    for line in newlines:
        t=t+1
        col = 0
        row = t
        worksheet.write(row, col, t)
        row = 0
        col = 3
        for word in list1:
            col = col+1
            worksheet.write(row, col, word)
    for line in newlines:
        row = row + 1
        col = 4
        for word in list1:
            counts = line.count(word)
            worksheet.write(row, col, counts)
            col = col + 1
        continue
    workbook.close()

# %%
main_download('ModelYAutoHomeBlog')

# %%
main_download('Model3AutoHomeBlog')

# %%
main_download('ModelSAutoHomeBlog')

# %%
main_download('ModelXAutoHomeBlog')

# %%
files = ["ModelYAutoHomeBlog.xlsx", "Model3AutoHomeBlog.xlsx", "ModelSAutoHomeBlog.xlsx", "ModelXAutoHomeBlog.xlsx"]

# %%
df_total = pd.DataFrame()
for file in files:  # loop through Excel files
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: # loop through sheets inside an Excel file
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('TeslaCombined.xlsx')

# %%
main_download('I3AutoHomeBlog')

# %%
main_download('IX3AutoHomeBlog')

# %%
main_download('BMW5AutoHomeBlog')

# %%
files = ["I3AutoHomeBlog.xlsx", "IX3AutoHomeBlog.xlsx", "BMW5AutoHomeBlog.xlsx"]

# %%
df_total = pd.DataFrame()
for file in files:  # loop through Excel files
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: # loop through sheets inside an Excel file
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('BMWCombined.xlsx')

# %%
main_download('ID-6XAutoHomeBlog')

# %%
main_download('ID4XAutoHomeBlog')

# %%
main_download('ID3AutoHomeBlog')

# %%
main_download('TuyueAutoHomeBlog')

# %%
files = ["ID-6XAutoHomeBlog.xlsx", "ID4XAutoHomeBlog.xlsx", "ID3AutoHomeBlog.xlsx", "TuyueAutoHomeBlog.xlsx"]

# %%
df_total = pd.DataFrame()
for file in files:  # loop through Excel files
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: # loop through sheets inside an Excel file
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('VolkswagenCombined.xlsx')

# %%
main_download('MustangMach-EAutoHomeBlog')

# %%
main_download('TerritoryAutoHomeBlog')

# %%
files = ['MustangMach-EAutoHomeBlog.xlsx','TerritoryAutoHomeBlog.xlsx']

# %%
df_total = pd.DataFrame()
for file in files:  
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: 
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('FordCombined.xlsx')

# %%
main_download('Q5EtronAutoHomeBlog')

# %%
main_download('EtronAutoHomeBlog')

# %%
files = ['Q5EtronAutoHomeBlog.xlsx','EtronAutoHomeBlog.xlsx']

# %%
df_total = pd.DataFrame()
for file in files:  # loop through Excel files
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: # loop through sheets inside an Excel file
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('AudiCombined.xlsx')

# %%
files = ["TeslaCombined.xlsx", "BMWCombined.xlsx", "VolkswagenCombined.xlsx", "FordCombined.xlsx", "AudiCombined.xlsx"]

# %%
df_total = pd.DataFrame()
for file in files:  
    if file.endswith('.xlsx'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: 
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('AllCombined.xlsx')
